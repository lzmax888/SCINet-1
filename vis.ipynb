# %%
import numpy as np
import seaborn as s

# %%
pred = np.load('exp/results/forecast_Norm.npy')

# %%
label = np.load('exp/results/target_Norm.npy')

# %%
pred.shape
# Out:
# (70730, 24, 2)

# %%
pred_sample = pred[100][:,-1]
label_sample = label[100][:,-1]

# %%
s.lineplot(data = pred_sample)
s.lineplot(data = label_sample)
# Out:
# <AxesSubplot:>

# %%
pred_sample = pred[1000][:,0]
label_sample = label[400][:,0]
s.lineplot(data = pred_sample)
#s.lineplot(data = label_sample)
# Out:
# <AxesSubplot:>

# %%
s.lineplot(data = label_sample)
# Out:
# <AxesSubplot:>

# %%
s.lineplot(data = pred[2000][:,0] )
s.lineplot(data = pred[100][:,0] )
# Out:
# <AxesSubplot:>
